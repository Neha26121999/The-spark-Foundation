# %% [markdown]
# # Task 1: Prediction using Supervised ML

# %% [markdown]
# Description : This is a simple linear regression task as it involves just 2 variables score and number of hours of studies.In                 this task we want to predict percentage of marks of an student based on the number of study hours.

# %%
#import all neccessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Import the Dataset

# %%
df=pd.read_csv("Marks.csv")
print("Dataset Loaded successfully!!!")
# Out:
# Dataset Loaded successfully!!!

# %%
df.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %% [markdown]
# # Data Visualization

# %%
df.plot(x='Hours', y='Scores',style="o")  
plt.title('Hours vs Percentage')  
plt.xlabel('Hours Studied')  
plt.ylabel('Percentage Score')  
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df.corr(),annot=True,cmap="BuPu")

# %%
plt.figure(figsize=(14,8))
sns.countplot("Scores",data=df)

# %%
sns.boxplot(x="Hours",data=df)

# %%
plt.figure(figsize=(14,8))
sns.barplot(x="Hours",y="Scores",data=df)

# %%
df.plot(y = 'Hours',kind='hist',color="pink")
plt.legend()
plt.show()

# %%
df.plot(y = 'Scores',kind='hist')
plt.legend()
plt.show()

# %% [markdown]
# # Data Wrangling

# %%
df.isnull().sum()
# Out:
# Hours     0
# Scores    0
# dtype: int64

# %%
df.corr()
# Out:
#            Hours    Scores
# Hours   1.000000  0.976191
# Scores  0.976191  1.000000

# %%
df.describe()
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %% [markdown]
# # Split the model into train and test model

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,1]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=1/3,random_state=0)

# %%
x_train.shape
# Out:
# (16, 1)

# %%
x_test.shape
# Out:
# (9, 1)

# %% [markdown]
# # Model Building

# %%
from sklearn.linear_model import LinearRegression
regressor=LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
y_pred=regressor.predict(x_test)

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})  
df
# Out:
#     Actual  Predicted
# 5       20  17.042892
# 2       27  33.516954
# 19      69  74.217577
# 16      30  26.733516
# 11      62  59.681640
# 22      35  39.331329
# 17      24  20.919142
# 24      86  78.093827
# 23      76  69.372265

# %%
# You can also test with your own data

own_pred = regressor.predict([[9.25]])

print("Predicted Score = {}".format(own_pred[0]))
# Out:
# Predicted Score = 92.14523314523314

# %% [markdown]
# # Visualizing the Training set Results

# %%
plt.scatter(x_train,y_train,color="red")
plt.plot(x_train,regressor.predict(x_train),color="blue")
plt.title('No. of hours vs Scores (Training set)')
plt.xlabel('No. of Hours')
plt.ylabel('Scores')
plt.show()

# %% [markdown]
# # Visualizing the Test set Results

# %%
plt.scatter(x_test,y_test,color="red")
plt.plot(x_train,regressor.predict(x_train),color="blue")
plt.title('No. of hours vs Scores (Test set)')
plt.xlabel('No. of Hours')
plt.ylabel('Scores')
plt.show()

# %% [markdown]
# # Evaluating the Model

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.955570080138813

# %%
from sklearn import metrics  
print('Mean Absolute Error:', 
      metrics.mean_absolute_error(y_test, y_pred))
# Out:
# Mean Absolute Error: 4.691397441397438

# %%
mse=metrics.mean_absolute_error(y_test, y_pred)
rmse=np.sqrt(mse)
rmse
# Out:
# 2.1659633979819324

# %% [markdown]
# # Thank You !!!

# %% [markdown]
# # Submitted By : Neha Srivastava
